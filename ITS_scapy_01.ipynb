# %% [markdown]
# <a href="https://colab.research.google.com/github/hanshenrikjeppesen/PythonNetworking/blob/master/ITS_scapy_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Scapy read pcap files

# %%
# %pip install scapy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 8.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scapy: filename=scapy-2.5.0-py2.py3-none-any.whl size=1444330 sha256=14d259de13151d966123ac5e0fef6942a5412c35110aa965613e25212988862f
#   Stored in directory: /root/.cache/pip/wheels/82/b7/03/8344d8cf6695624746311bc0d389e9d05535ca83c35f90241d
# Successfully built scapy
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e73be2b4-4c69-4078-8249-d58e45489763" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e73be2b4-4c69-4078-8249-d58e45489763">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from scapy.all import *

# %%
packets = rdpcap("telnet-raw.pcap")

# %%
for packet in packets:
  print(packet.summary)
# Out:
# <bound method Packet.summary of <Ether  dst=00:00:c0:9f:a0:97 src=00:a0:cc:3b:bf:fa type=IPv4 |<IP  version=4 ihl=5 tos=0x10 len=60 id=5799 flags=DF frag=0 ttl=64 proto=6 chksum=0xa2b1 src=192.168.0.2 dst=192.168.0.1 |<TCP  sport=1254 dport=23 seq=72603759 ack=0 dataofs=10 reserved=0 flags=S window=32120 chksum=0x5d40 urgptr=0 options=[('MSS', 1460), ('SAckOK', b''), ('Timestamp', (1444389, 0)), ('NOP', None), ('WScale', 0)] |>>>>
# <bound method Packet.summary of <Ether  dst=00:a0:cc:3b:bf:fa src=00:00:c0:9f:a0:97 type=IPv4 |<IP  version=4 ihl=5 tos=0x0 len=60 id=29797 flags= frag=0 ttl=64 proto=6 chksum=0x8503 src=192.168.0.1 dst=192.168.0.2 |<TCP  sport=23 dport=1254 seq=3225454542 ack=72603760 dataofs=10 reserved=0 flags=SA window=17376 chksum=0x65d urgptr=0 options=[('MSS', 1448), ('NOP', None), ('WScale', 0), ('NOP', None), ('NOP', None), ('Timestamp', (346979, 1444389))] |>>>>
# ...
